# %% [markdown]
# ### Matplotlib

# %% [markdown]
# #### Matplotlib is a plotting library for the Python programming language and its numerical mathematics extension NumPy.
#
# #### Matplotlib is an amazing visualization library in Python for 2D plots of arrays. Matplotlib is a multi-platform data visualization library built on NumPy arrays and designed to work with the broader SciPy stack. It was introduced by John Hunter in the year 2002.

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
x=np.arange(0,10)
y=np.arange(11,21)

# %%
#plotting using matplotlib 

##plt scatter

plt.scatter(x,y,c='r')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Graph in 2D')
plt.savefig('G:\Stuff\Graph in 2D.jpg')

# %%
y=x*x

# %%
## plt plot

plt.plot(x,y,'g*',linestyle='dashed',linewidth=2,markersize=12)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('2D diagram')
# Out:
# Text(0.5, 1.0, '2D diagram')

# %%
# Creating Subplots

plt.subplot(2,2,1)
plt.plot(x,y,'r--')
plt.subplot(2,2,2)
plt.plot(x,y,'g*--')
plt.subplot(2,2,3)
plt.plot(x,y,'b^--')
plt.subplot(2,2,4)
plt.plot(x,y,'yo')

# %%
a=np.arange(1,11)
b=3*a**2 + 2*a + 5
plt.plot(a,b)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Matplotlib demo')
# Out:
# Text(0.5, 1.0, 'Matplotlib demo')

# %%
# Compute the x and y coordinates for points on a sine curve 

x= np.arange(0,5*np.pi,0.3)
y= np.sin(x)
plt.plot(x,y)
plt.title('Sine Wave')
# Out:
# Text(0.5, 1.0, 'Sine Wave')

# %%
x= np.arange(0,5*np.pi,0.3)
y_sin= np.sin(x)
y_cos= np.cos(x)

plt.subplot(2,1,1)
plt.plot(x,y_sin,'r*--')
plt.title('Sine Wave')

plt.subplot(2,1,2)
plt.plot(x,y_cos,'g*--')
plt.title('Cosine Wave')
# Out:
# Text(0.5, 1.0, 'Cosine Wave')

# %%
## Bar Plot

x = [2,8,10] 
y = [11,16,9]  

x2 = [3,9,11] 
y2 = [6,15,7] 

plt.bar(x,y,color='b')
plt.bar(x2,y2,color='g')
plt.title('Bar Graph')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
# Histograms

a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27]) 
plt.hist(a,bins=10)
plt.title('Histogram')
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
# Box Plot

data =[np.random.normal(0,std,100) for std in range(1,5)]
plt.boxplot(data,vert=True,patch_artist=True);

# %%
data
# Out:
# [array([-5.55004910e-01,  5.30849412e-02,  3.03947734e-01,  5.65513449e-01,
#         -4.90455556e-01, -1.75251600e+00, -2.99301432e-01, -4.02533178e-02,
#         -5.41459806e-01,  1.16673502e+00,  7.20384890e-01,  1.54663168e+00,
#          7.09108417e-01,  2.25103078e-01,  1.44123550e+00, -3.53462390e-01,
#          5.60918278e-01, -1.02512025e-01, -1.69443285e+00,  6.50922516e-02,
#         -8.53611992e-01,  1.66764753e+00,  2.00605234e-01, -8.65513600e-01,
#         -7.64696682e-01,  1.05851838e+00,  6.24879069e-03, -8.79257330e-01,
#          2.88189297e-01,  1.34192369e+00, -4.10051308e-01,  6.44909699e-01,
#         -1.14979648e+00, -1.14334162e+00, -4.89100877e-01,  1.43968040e-02,
#         -4.54173813e-01, -3.84863402e-01, -1.76201356e+00, -2.26317024e+00,
#         -1.32476874e+00, -1.53298913e-01,  6.30943809e-01,  1.36391470e+00,
#         -2.35646683e-01, -8.80675759e-01,  5.68540307e-01, -6.95831914e-01,
