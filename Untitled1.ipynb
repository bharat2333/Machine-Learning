# %%
a=['satya','bharat','kona']
[a[i]*3 for i in range(len(a))]
[3 for i in range(10)]
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3]

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
b=np.arange(len(a))
c=[10,6,3]
plt.bar(b,c)
plt.xticks(b,a)
# Out:
# ([<matplotlib.axis.XTick at 0x1d6f89d1340>,
#   <matplotlib.axis.XTick at 0x1d6f89d12e0>,
#   <matplotlib.axis.XTick at 0x1d6f89d1a90>],
#  <a list of 3 Text xticklabel objects>)

# %%
plt.bar(range(1,6), np.random.randint(1,20,5))
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(10,8))
N = 60
g1 = (0.6 + 0.6 * np.random.rand(N), np.random.rand(N))
g2 = (0.4+0.3 * np.random.rand(N), 0.5*np.random.rand(N))
g3 = (0.3*np.random.rand(N), 0.3*np.random.rand(N))
data = (g1, g2, g3)
colors = ("red", "green", "blue")
groups = ("coffee", "tea", "water")
for data,i,j in zip(data,colors,groups):
    x,y=data
    plt.scatter(x,y,alpha=0.8,c=i,s=30,label=j)
x=np.random.rand(10)
y=x
plt.plot(x,y)
plt.grid(True,which='both')
plt.axhline(y=0.5,color='m')
plt.axvline(x=0.5,color='m')

# %%
a=np.arange(50)
b=np.sin(a)
plt.figure(figsize=(8,4),facecolor='y')
plt.plot(a,b)
